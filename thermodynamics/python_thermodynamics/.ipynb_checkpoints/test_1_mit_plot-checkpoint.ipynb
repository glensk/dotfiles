# %%
ls
# Out:
# DOS_POSITIONS_auswerten.py*   crystal_generator.pyc  feos.py*   hesse.py.save*  pot_energy_forces.py*  pot_parametrize.pyc                            tags
# Untitled0.ipynb               fah.py*                fqh.py*    my_atom.py*     pot_energy_forces.pyc  qubus_interpolate.py*                          thermodynamics.py*
# calculate_energy_and_forces*  fah_dudl.py*           hesse.py*  my_atom.pyc     pot_info_startjob.py*  qubus_map_vecs_to_first_quadrant_and_back.py*  utils.py*
# crystal_generator.py*         fel.py*                hesse.pyc  pot.py*         pot_parametrize.py*    save_old/                                      utils.pyc

# %%
pwd
# Out:
# u'/Users/glensk/Dropbox/Thermodynamics/python_thermodynamics'

# %%
# %matplotlib inline
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
sns.jointplot("total_bill", "tip", tips, kind='reg');
